# %%
import numpy as np
import sys, os
from pathlib import Path

current_dir = os.getcwd()

for p in ['../..', '../../python', '../../lib', '../../core/pydis/python', '../../core/exadis/python']:
    abs_path = os.path.abspath(os.path.join(current_dir, p))
    if abs_path not in sys.path:
        sys.path.insert(0, abs_path)

# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection

import pyexadis
from pyexadis_base import ExaDisNet, DisNetManager, VisualizeNetwork

pyexadis.initialize()
# Out:
# Device Execution Space:
#   KOKKOS_ENABLE_CUDA: yes
# Cuda Options:
#   KOKKOS_ENABLE_CUDA_RELOCATABLE_DEVICE_CODE: no
#   KOKKOS_ENABLE_CUDA_UVM: no
#   KOKKOS_ENABLE_IMPL_CUDA_MALLOC_ASYNC: no
#
# Cuda Runtime Configuration:
# macro  KOKKOS_ENABLE_CUDA      : defined
# macro  CUDA_VERSION          =
# Kokkos::OpenMP::initialize WARNING: OMP_PROC_BIND environment variable not set
#   In general, for best performance with OpenMP 4.0 or better set OMP_PROC_BIND=spread and OMP_PLACES=threads
#   For best performance with OpenMP 3.1 set OMP_PROC_BIND=true
#   For unit testing set OMP_PROC_BIND=false
# 12040 = version 12.4
# Kokkos::Cuda[ 0 ] NVIDIA RTX 2000 Ada Generation Laptop GPU : Selected
#   Capability: 8.9
#   Total Global Memory: 7.623 GiB
#   Shared Memory per Block: 48 KiB
#   Can access system allocated memory: 0
#     via Address Translation Service: 0
# Reading ParaDiS configuration
#  Input file: output_climb/initial.config
#  nodes: 24, segments: 24
# ...

# %%
input_file = "output_climb/initial.config"

G = ExaDisNet().read_paradis(input_file)
net = DisNetManager(G)

my_bounds = [[0, 0, 0], [1000, 1000, 1000]]

vis = VisualizeNetwork(view_init={"elev": 30, "azim": -150})
vis.plot_disnet(net)

plt.show()
# Out:
# Reading ParaDiS configuration
#  Input file: output_climb/initial.config
#  nodes: 24, segments: 24
#  Burgers vector is conserved for all nodes

# %%
pyexadis.finalize()
